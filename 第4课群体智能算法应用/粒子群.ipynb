# %%
import numpy as np
import matplotlib.pyplot as plt
 
 
class PSO(object):
    def __init__(self, population_size, max_steps):
        self.w = 0.6  # 惯性权重
        self.c1 = self.c2 = 2
        self.population_size = population_size  # 粒子群数量
        self.dim = 2  # 搜索空间的维度
        self.max_steps = max_steps  # 迭代次数
        self.x_bound = [-10, 10]  # 解空间范围
        self.x = np.random.uniform(self.x_bound[0], self.x_bound[1],
                                   (self.population_size, self.dim))  # 初始化粒子群位置
        self.v = np.random.rand(self.population_size, self.dim)  # 初始化粒子群速度
        fitness = self.calculate_fitness(self.x)
        self.p = self.x  # 个体的最佳位置
        self.pg = self.x[np.argmin(fitness)]  # 全局最佳位置
        self.individual_best_fitness = fitness  # 个体的最优适应度
        self.global_best_fitness = np.min(fitness)  # 全局最佳适应度
 
    def calculate_fitness(self, x):
        return np.sum(np.square(x), axis=1)
 
    def evolve(self):
        fig = plt.figure()
        for step in range(self.max_steps):
            r1 = np.random.rand(self.population_size, self.dim)
            r2 = np.random.rand(self.population_size, self.dim)
            # 更新速度和权重
            self.v = self.w*self.v+self.c1*r1*(self.p-self.x)+self.c2*r2*(self.pg-self.x)
            self.x = self.v + self.x
            plt.clf()
            plt.scatter(self.x[:, 0], self.x[:, 1], s=30, color='k')
            plt.xlim(self.x_bound[0], self.x_bound[1])
            plt.ylim(self.x_bound[0], self.x_bound[1])
            plt.pause(0.01)
            fitness = self.calculate_fitness(self.x)
            # 需要更新的个体
            update_id = np.greater(self.individual_best_fitness, fitness)
            self.p[update_id] = self.x[update_id]
            self.individual_best_fitness[update_id] = fitness[update_id]
            # 新一代出现了更小的fitness，所以更新全局最优fitness和位置
            if np.min(fitness) < self.global_best_fitness:
                self.pg = self.x[np.argmin(fitness)]
                self.global_best_fitness = np.min(fitness)
            print('best fitness: %.5f, mean fitness: %.5f' % (self.global_best_fitness, np.mean(fitness)))
 
 
pso = PSO(100, 100)
pso.evolve()
plt.show()
# Out:
# best fitness: 0.00907, mean fitness: 26.94955
# best fitness: 0.00907, mean fitness: 32.38550
# best fitness: 0.00907, mean fitness: 24.57519
# best fitness: 0.00248, mean fitness: 29.89126
# best fitness: 0.00248, mean fitness: 28.97725
# best fitness: 0.00248, mean fitness: 29.33019
# best fitness: 0.00248, mean fitness: 35.24090
# best fitness: 0.00248, mean fitness: 26.40667
# best fitness: 0.00248, mean fitness: 18.88411
# best fitness: 0.00248, mean fitness: 21.56242
# best fitness: 0.00248, mean fitness: 24.56396
# best fitness: 0.00020, mean fitness: 18.33787
# best fitness: 0.00020, mean fitness: 13.60504
# best fitness: 0.00020, mean fitness: 15.13623
# best fitness: 0.00020, mean fitness: 21.58302
# best fitness: 0.00020, mean fitness: 21.98898
# best fitness: 0.00020, mean fitness: 18.34019
# best fitness: 0.00020, mean fitness: 25.05821
# best fitness: 0.00020, mean fitness: 9.79839
# best fitness: 0.00020, mean fitness: 15.79931
# best fitness: 0.00000, mean fitness: 0.21624
# best fitness: 0.00000, mean fitness: 0.28284
# best fitness: 0.00000, mean fitness: 0.40084
# best fitness: 0.00000, mean fitness: 1.18220
# best fitness: 0.00000, mean fitness: 0.83551
# best fitness: 0.00000, mean fitness: 0.34554
# best fitness: 0.00000, mean fitness: 2.21712
# best fitness: 0.00000, mean fitness: 1.09926
# best fitness: 0.00000, mean fitness: 1.53155
# best fitness: 0.00000, mean fitness: 8.65930
# best fitness: 0.00000, mean fitness: 1.70807
# best fitness: 0.00000, mean fitness: 8.16731
# best fitness: 0.00000, mean fitness: 2.80932
# best fitness: 0.00000, mean fitness: 4.13024
# best fitness: 0.00000, mean fitness: 0.49157
# best fitness: 0.00000, mean fitness: 4.36990
# best fitness: 0.00000, mean fitness: 15.94916
# best fitness: 0.00000, mean fitness: 16.78812
# best fitness: 0.00000, mean fitness: 19.47674

# %%
import numpy as np
import matplotlib.pyplot as plt
class PSO(object):
    def init(self, population_size, max_steps):
        self.w = 0.6  # 惯性权重
        self.c1 = self.c2 = 2
        self.population_size = population_size  # 粒子群数量
        self.dim = 1  # 搜索空间的维度
        self.max_steps = max_steps  # 迭代次数
        self.x_bound = [0, 9.9]  # 解空间范围
        self.x = np.random.uniform(self.x_bound[0], self.x_bound[1],
                                   (self.population_size, self.dim))  # 初始化粒子群位置
        self.v = np.random.rand(self.population_size, self.dim)  # 初始化粒子群速度
        fitness = self.calculate_fitness(self.x)
        self.p = self.x  # 个体的最佳位置
        self.pg = self.x[np.argmin(fitness)]  # 全局最佳位置
        self.individual_best_fitness = fitness  # 个体的最优适应度
        self.global_best_fitness = np.min(fitness)  # 全局最佳适应度 
    def calculate_fitness(self, x):
        return x * np.sin(10 * x) + x * np.cos(2 * x)
    def evolve(self):
        fig = plt.figure()
        for step in range(self.max_steps):
            r1 = np.random.rand(self.population_size, self.dim)
            r2 = np.random.rand(self.population_size, self.dim)
            # 更新速度和权重
            self.v = self.w*self.v+self.c1*r1*(self.p-self.x)+self.c2*r2*(self.pg-self.x)
            self.x = self.v + self.x
            plt.clf()
            plt.scatter(self.x, self.calculate_fitness(self.x), s=30, color='k')
            plt.xlim(self.x_bound[0], self.x_bound[1])
            plt.ylim(-20, 20)
            plt.pause(0.01)
            fitness = self.calculate_fitness(self.x)
            # 需要更新的个体
            update_id = np.greater(self.individual_best_fitness, fitness)
            self.p[update_id] = self.x[update_id]
            self.individual_best_fitness[update_id] = fitness[update_id]
            # 新一代出现了更小的fitness，所以更新全局最优fitness和位置
            if np.min(fitness) < self.global_best_fitness:
                self.pg = self.x[np.argmin(fitness)]
                self.global_best_fitness = np.min(fitness)
            print('best fitness: %.5f, mean fitness: %.5f' %self.global_best_fitness, np.mean(fitness))
pso = PSO()
pso.init(population_size=50, max_steps=100)
pso.evolve()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c707d69a2ac2> in <module>
#      44 pso = PSO()
#      45 pso.init(population_size=50, max_steps=100)
# ---> 46 pso.evolve()
#      47 plt.show()
#
# <ipython-input-4-c707d69a2ac2> in evolve(self)
#      41                 self.pg = self.x[np.argmin(fitness)]
#      42                 self.global_best_fitness = np.min(fitness)
# ---> 43             print('best fitness: %.5f, mean fitness: %.5f' %self.global_best_fitness, np.mean(fitness))
#      44 pso = PSO()
#      45 pso.init(population_size=50, max_steps=100)
#
# TypeError: not enough arguments for format string

# %%
import numpy as np
import matplotlib.pyplot as plt
class PSO(object):
    def init(self, population_size, max_steps):
        self.w = 0.6  # 惯性权重
        self.c1 = self.c2 = 2
        self.population_size = population_size  # 粒子群数量
        self.dim = 1  # 搜索空间的维度
        self.max_steps = max_steps  # 迭代次数
        self.x_bound = [0, 9.9]  # 解空间范围
        self.x = np.random.uniform(self.x_bound[0], self.x_bound[1],
                                   (self.population_size, self.dim))  # 初始化粒子群位置
        self.v = np.random.rand(self.population_size, self.dim)  # 初始化粒子群速度
        fitness = self.calculate_fitness(self.x)
        self.p = self.x  # 个体的最佳位置
        self.pg = self.x[np.argmin(fitness)]  # 全局最佳位置
        self.individual_best_fitness = fitness  # 个体的最优适应度
        self.global_best_fitness = np.min(fitness)  # 全局最佳适应度 
    def calculate_fitness(self, x):
        return x * np.sin(10 * x) + x * np.cos(2 * x)
    def evolve(self):
        fig = plt.figure()
        for step in range(self.max_steps):
            r1 = np.random.rand(self.population_size, self.dim)
            r2 = np.random.rand(self.population_size, self.dim)
            # 更新速度和权重
            self.v = self.w*self.v+self.c1*r1*(self.p-self.x)+self.c2*r2*(self.pg-self.x)
            self.x = self.v + self.x
            plt.clf()
            plt.scatter(self.x, self.calculate_fitness(self.x), s=30, color='k')
            plt.xlim(self.x_bound[0], self.x_bound[1])
            plt.ylim(-20, 20)
            plt.pause(0.01)
            fitness = self.calculate_fitness(self.x)
            # 需要更新的个体
            update_id = np.greater(self.individual_best_fitness, fitness)
            self.p[update_id] = self.x[update_id]
            self.individual_best_fitness[update_id] = fitness[update_id]
            # 新一代出现了更小的fitness，所以更新全局最优fitness和位置
            if np.min(fitness) < self.global_best_fitness:
                self.pg = self.x[np.argmin(fitness)]
                self.global_best_fitness = np.min(fitness)
            print('best fitness: %.5f, mean fitness: %.5f' %self.global_best_fitness, np.mean(fitness))
pso = PSO()
pso.init(population_size=50, max_steps=100)
pso.evolve()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c707d69a2ac2> in <module>
#      44 pso = PSO()
#      45 pso.init(population_size=50, max_steps=100)
# ---> 46 pso.evolve()
#      47 plt.show()
#
# <ipython-input-6-c707d69a2ac2> in evolve(self)
#      41                 self.pg = self.x[np.argmin(fitness)]
#      42                 self.global_best_fitness = np.min(fitness)
# ---> 43             print('best fitness: %.5f, mean fitness: %.5f' %self.global_best_fitness, np.mean(fitness))
#      44 pso = PSO()
#      45 pso.init(population_size=50, max_steps=100)
#
# TypeError: not enough arguments for format string
